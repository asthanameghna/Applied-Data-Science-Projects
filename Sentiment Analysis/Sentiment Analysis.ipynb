# %% [markdown]
# # Sentiment Analysis
#
# This project deals with the analysis of sentiment of tweets. It has been achieved by training Multinomial Naive Bayes and Linear Support Vector Classifier models. We have achieved accuracy scores of 74% and 71% for the models respectively.

# %% [markdown]
# ### 1. Importing Libraries

# %%
import pandas
import matplotlib.pyplot as plt
import string

import re
from string import punctuation
from collections import Counter

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.externals import joblib
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# ### 2. Reading the csv file and converting into Pandas Dataframe

# %%
tweets = pandas.read_csv('tweets_sentiment.csv',  encoding='ISO8859-1')
tweetsdf = pandas.DataFrame(tweets['Sentiment'], columns=['Sentiment'])
tweetsdf['Sentiment Text'] = tweets['SentimentText']
tweetsdf
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          Sentiment                                     Sentiment Text
# 0                0                       is so sad for my APL frie...
# 1                0                     I missed the New Moon trail...
# 2                1                            omg its already 7:30 :O
# 3                0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4                0           i think mi bf is cheating on me!!!   ...
# 5                0                  or i just worry too much?
# 6                1                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7                0         Sunny Again        Work Tomorrow  :-|  ...
# 8                1        handed in my uniform today . i miss you ...
# 9                1           hmmmm.... i wonder how she my number @-)
# 10               0                      I must think about positive..
# 11               1        thanks to all the haters up in my face a...
# 12               0                     this weekend has sucked so far
# 13               0             jb isnt showing in australia any more!
# 14               0                               ok thats it you win.
# 15               0      &lt;-------- This is the way i feel right ...
# 16               0      awhhe man.... I'm completely useless rt no...
# 17               1      Feeling strangely fine. Now I'm gonna go l...
# 18               0       HUGE roll of thunder just now...SO scary!!!!
# 19               0      I just cut my beard off. It's only been gr...
# 20               0                               Very sad about Iran.
# 21               0                                      wompppp wompp
# 22               1      You're the only one who can see this cause...
# 23               0     &lt;---Sad level is 3. I was writing a mass...
# 24               0     ...  Headed to Hospitol : Had to pull out o...
# 25               0     BoRinG   ): whats wrong with him??     Plea...
# 26               0     can't be bothered. i wish i could spend the...
# 27               0     Feeeling like shit right now. I really want...
# 28               1              goodbye exams, HELLO ALCOHOL TONIGHT
# 29               0     I didn't realize it was THAT deep. Geez giv...
# ...            ...                                                ...
# 1048545          0  Missing my Boy's poetry concert tonight. Hate ...
# 1048546          0    missing my boys touch and trying NOT to freeze
# 1048547          0                                  Missing my buddy
# 1048548          0            Missing my bundle of brilliant fun....
# 1048549          0                Missing my Butterflies (as always)
# 1048550          0                                    Missing my cat
# 1048551          0  Missing my cats so so so much right now   Relo...
# 1048552          0               Missing my comcast I HATE direct tv
# 1048553          0                                missing my corbear
# 1048554          0             Missing my dad &amp; my brother today
# 1048555          0                                   Missing my Dad!
# 1048556          1  missing my daddio and laughing with him. i get...
# 1048557          0  Missing my daddy this weekend  I still miss hi...
# 1048558          0     Missing my daddy today. RIP 1/17/44 - 1/19/98
# 1048559          0  Missing my daddy today. Some days i feel furth...
# 1048560          0                                 missing my daddy.
# 1048561          0     missing my daily dose of Scrabble on Facebook
# 1048562          0  missing my dear amandafriends  all alone fixin...
# 1048563          0  Missing my dearest love so much!  learning for...
# 1048564          0  missing my dude  I go back to him in 10 days  ...
# 1048565          0  Missing my fam in WA, want to see g-ma before ...
# 1048566          0                                 missing my family
# 1048567          0                      Missing my family in the USA
# 1048568          0                    Missing my family lots tonight
# 1048569          0                               Missing my fiance'
# 1048570          0  Missing my fiancee sooo badly!!!  I love you b...
# 1048571          0                                 missing my friend
# 1048572          0  Missing my friend and my cousin. Two months pa...
# 1048573          0                               missing my friends!
# 1048574          0                              Missing my friends!!
#
# [1048575 rows x 2 columns]

# %% [markdown]
# ### 3. Cleaning up Sentiment Text

# %%
# helper function to clean tweets
def processTweet(tweet):
    # Remove HTML special entities (e.g. &amp;)
    tweet = re.sub(r'\&\w*;', '', tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','',tweet)
    # Remove tickers
    tweet = re.sub(r'\$\w*', '', tweet)
    # To lowercase
    tweet = tweet.lower()
    # Remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*\/\w*', '', tweet)
    # Remove hashtags
    tweet = re.sub(r'#\w*', '', tweet)
    # Remove Punctuation and split 's, 't, 've with a space for filter
    tweet = re.sub(r'[' + punctuation.replace('@', '') + ']+', ' ', tweet)
    # Remove words with 2 or fewer letters
    tweet = re.sub(r'\b\w{1,2}\b', '', tweet)
    # Remove whitespace (including new line characters)
    tweet = re.sub(r'\s\s+', ' ', tweet)
    # Remove single space remaining at the front of the tweet.
    tweet = tweet.lstrip(' ') 
    # Remove characters beyond Basic Multilingual Plane (BMP) of Unicode:
    tweet = ''.join(c for c in tweet if c <= '\uFFFF') 
    return tweet
# ______________________________________________________________
# clean dataframe's text column
tweetsdf['Sentiment Text'] = tweetsdf['Sentiment Text'].apply(processTweet)
# preview some cleaned tweets
tweetsdf
# Out:
#          Sentiment                                     Sentiment Text
# 0                0                                sad for apl friend
# 1                0                       missed the new moon trailer
# 2                1                                   omg its already
# 3                0  omgaga sooo gunna cry been this dentist since ...
# 4                0                                    think cheating
# 5                0                               just worry too much
# 6                1                  juuuuuuuuuuuuuuuuussssst chillin
# 7                0                  sunny again work tomorrow tonight
# 8                1              handed uniform today miss you already
# 9                1                       hmmmm wonder how she number
# 10               0                         must think about positive
# 11               1         thanks all the haters face all day 112 102
# 12               0                        this weekend has sucked far
# 13               0                   isnt showing australia any more
# 14               0                                     thats you win
# 15               0                       this the way feel right now
# 16               0  awhhe man completely useless now funny all can...
# 17               1  feeling strangely fine now gonna listen some s...
# 18               0                  huge roll thunder just now scary
# 19               0  just cut beard off only been growing for well ...
# 20               0                               very sad about iran
# 21               0                                      wompppp wompp
# 22               1  you the only one who can see this cause one el...
# 23               0  sad level was writing massive blog tweet myspa...
# 24               0  headed hospitol had pull out the golf tourny 3...
# 25               0           boring whats wrong with him please tell
# 26               0  can bothered wish could spend the rest life ju...
# 27               0  feeeling like shit right now really want sleep...
# 28               1               goodbye exams hello alcohol tonight
# 29               0  didn realize was that deep geez give girl warn...
# ...            ...                                                ...
# 1048545          0      missing boy poetry concert tonight hate that
# 1048546          0          missing boys touch and trying not freeze
# 1048547          0                                     missing buddy
# 1048548          0                      missing bundle brilliant fun
# 1048549          0                        missing butterflies always
# 1048550          0                                       missing cat
# 1048551          0  missing cats much right now relocating hard ha...
# 1048552          0                       missing comcast hate direct
# 1048553          0                                   missing corbear
# 1048554          0                         missing dad brother today
# 1048555          0                                       missing dad
# 1048556          1  missing daddio and laughing with him get all f...
# 1048557          0  missing daddy this weekend still miss him each...
# 1048558          0                           missing daddy today rip
# 1048559          0  missing daddy today some days feel further awa...
# 1048560          0                                     missing daddy
# 1048561          0              missing daily dose scrabble facebook
# 1048562          0  missing dear amandafriends all alone fixing po...
# 1048563          0  missing dearest love much learning for history...
# 1048564          0        missing dude back him days byebye michigan
# 1048565          0  missing fam want see before too late time grow...
# 1048566          0                                    missing family
# 1048567          0                            missing family the usa
# 1048568          0                       missing family lots tonight
# 1048569          0                                    missing fiance
# 1048570          0        missing fiancee sooo badly love you baybay
# 1048571          0                                    missing friend
# 1048572          0  missing friend and cousin two months passed qu...
# 1048573          0                                   missing friends
# 1048574          0                                   missing friends
#
# [1048575 rows x 2 columns]

# %% [markdown]
# ### 4. Grouping Tweets by Sentiment

# %%
# check the number of positive vs. negative tagged sentences
positives = tweetsdf['Sentiment'][tweetsdf.Sentiment == 0]
negatives = tweetsdf['Sentiment'][tweetsdf.Sentiment == 1]


print('number of positve tagged sentences is:  {}'.format(len(positives)))
print('number of negative tagged sentences is: {}'.format(len(negatives)))
print('total length of the data is:            {}'.format(tweetsdf.shape[0]))
# Out:
# number of positve tagged sentences is:  494105
# number of negative tagged sentences is: 554470
# total length of the data is:            1048575

# %%
# get unique label counts
tweetsdf.groupby('Sentiment').describe()
# Out:
#           Sentiment Text
#                    count  unique top  freq
# Sentiment
# 0                 494105  474344      1813
# 1                 554470  521254      2076

# %% [markdown]
# ### 5. Counting no. of words in each tweet

# %%
# get a word count per sentence column
def count_no_of_words(sentence):
    return len(sentence.split())
    
tweetsdf['word count'] = tweetsdf['Sentiment Text'].apply(count_no_of_words)
tweetsdf
# Out:
#          Sentiment                                     Sentiment Text  \
# 0                0                                sad for apl friend
# 1                0                       missed the new moon trailer
# 2                1                                   omg its already
# 3                0  omgaga sooo gunna cry been this dentist since ...
# 4                0                                    think cheating
# 5                0                               just worry too much
# 6                1                  juuuuuuuuuuuuuuuuussssst chillin
# 7                0                  sunny again work tomorrow tonight
# 8                1              handed uniform today miss you already
# 9                1                       hmmmm wonder how she number
# 10               0                         must think about positive
# 11               1         thanks all the haters face all day 112 102
# 12               0                        this weekend has sucked far
# 13               0                   isnt showing australia any more
# 14               0                                     thats you win
# 15               0                       this the way feel right now
# 16               0  awhhe man completely useless now funny all can...
# 17               1  feeling strangely fine now gonna listen some s...
# 18               0                  huge roll thunder just now scary
# 19               0  just cut beard off only been growing for well ...
# 20               0                               very sad about iran
# 21               0                                      wompppp wompp
# 22               1  you the only one who can see this cause one el...
# 23               0  sad level was writing massive blog tweet myspa...
# 24               0  headed hospitol had pull out the golf tourny 3...
# 25               0           boring whats wrong with him please tell
# 26               0  can bothered wish could spend the rest life ju...
# 27               0  feeeling like shit right now really want sleep...
# 28               1               goodbye exams hello alcohol tonight
# 29               0  didn realize was that deep geez give girl warn...
# ...            ...                                                ...
# 1048545          0      missing boy poetry concert tonight hate that
# 1048546          0          missing boys touch and trying not freeze
# 1048547          0                                     missing buddy
# 1048548          0                      missing bundle brilliant fun
# 1048549          0                        missing butterflies always
# 1048550          0                                       missing cat
# 1048551          0  missing cats much right now relocating hard ha...
# 1048552          0                       missing comcast hate direct
# 1048553          0                                   missing corbear
# 1048554          0                         missing dad brother today
# 1048555          0                                       missing dad
# 1048556          1  missing daddio and laughing with him get all f...
# 1048557          0  missing daddy this weekend still miss him each...
# 1048558          0                           missing daddy today rip
# 1048559          0  missing daddy today some days feel further awa...
# 1048560          0                                     missing daddy
# 1048561          0              missing daily dose scrabble facebook
# 1048562          0  missing dear amandafriends all alone fixing po...
# 1048563          0  missing dearest love much learning for history...
# 1048564          0        missing dude back him days byebye michigan
# 1048565          0  missing fam want see before too late time grow...
# 1048566          0                                    missing family
# 1048567          0                            missing family the usa
# 1048568          0                       missing family lots tonight
# 1048569          0                                    missing fiance
# 1048570          0        missing fiancee sooo badly love you baybay
# 1048571          0                                    missing friend
# 1048572          0  missing friend and cousin two months passed qu...
# 1048573          0                                   missing friends
# 1048574          0                                   missing friends
#
#          word count
# 0                 4
# 1                 5
# 2                 3
# 3                15
# 4                 2
# 5                 4
# 6                 2
# 7                 5
# 8                 6
# 9                 5
# 10                4
# 11                9
# 12                5
# 13                5
# 14                3
# 15                6
# 16                9
# 17                9
# 18                6
# 19               17
# 20                4
# 21                2
# 22               19
# 23               18
# 24               15
# 25                7
# 26               15
# 27               17
# 28                5
# 29               10
# ...             ...
# 1048545           7
# 1048546           7
# 1048547           2
# 1048548           4
# 1048549           3
# 1048550           2
# 1048551          10
# 1048552           4
# 1048553           2
# 1048554           4
# 1048555           2
# 1048556          15
# 1048557          11
# 1048558           4
# 1048559          10
# 1048560           2
# 1048561           5
# 1048562           9
# 1048563           8
# 1048564           7
# 1048565          10
# 1048566           2
# 1048567           4
# 1048568           4
# 1048569           2
# 1048570           7
# 1048571           2
# 1048572           8
# 1048573           2
# 1048574           2
#
# [1048575 rows x 3 columns]

# %%
# get most common words in training dataset
all_words = []
for line in list(tweetsdf['Sentiment Text']):
    words = line.split()
    for word in words:
        all_words.append(word.lower())
    
    
Counter(all_words).most_common(10)
# Out:
# [('the', 331194),
#  ('you', 243592),
#  ('and', 194491),
#  ('for', 138131),
#  ('that', 122362),
#  ('have', 102096),
#  ('but', 92359),
#  ('just', 88702),
#  ('with', 71530),
#  ('not', 70742)]

# %%
# drop duplicates
tweetsdf = tweetsdf.drop_duplicates('Sentiment Text')
tweetsdf.shape
# Out:
# (993412, 3)

# %% [markdown]
# ### 6. Removing stopwords and Tokenization

# %%
# show stop words examples
stop_words = ['i' , 'me' , 'my' , 'myself' , 'we' , 'our' , 'ours' , 'ourselves' , 'you' , 'you\'re' , 'you\'ve' , 'you\'ll' , 'you\'d' , 'your' , 'yours' , 'yourself' , 'yourselves' , 'he' , 'him' , 'his' , 'himself' , 'she' , 'her' , 'hers' , 'herself' , 'it']

# %%
# tokenize helper function
def text_process(raw_text):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in list(raw_text) if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.lower().split() if word.lower() not in stop_words]


# tokenize message column and create a column for tokens
tweetsdf['tokens'] = tweetsdf['Sentiment Text'].apply(text_process) # tokenize style 1

tweetsdf
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          Sentiment                                     Sentiment Text  \
# 0                0                                sad for apl friend
# 1                0                       missed the new moon trailer
# 2                1                                   omg its already
# 3                0  omgaga sooo gunna cry been this dentist since ...
# 4                0                                    think cheating
# 5                0                               just worry too much
# 6                1                  juuuuuuuuuuuuuuuuussssst chillin
# 7                0                  sunny again work tomorrow tonight
# 8                1              handed uniform today miss you already
# 9                1                       hmmmm wonder how she number
# 10               0                         must think about positive
# 11               1         thanks all the haters face all day 112 102
# 12               0                        this weekend has sucked far
# 13               0                   isnt showing australia any more
# 14               0                                     thats you win
# 15               0                       this the way feel right now
# 16               0  awhhe man completely useless now funny all can...
# 17               1  feeling strangely fine now gonna listen some s...
# 18               0                  huge roll thunder just now scary
# 19               0  just cut beard off only been growing for well ...
# 20               0                               very sad about iran
# 21               0                                      wompppp wompp
# 22               1  you the only one who can see this cause one el...
# 23               0  sad level was writing massive blog tweet myspa...
# 24               0  headed hospitol had pull out the golf tourny 3...
# 25               0           boring whats wrong with him please tell
# 26               0  can bothered wish could spend the rest life ju...
# 27               0  feeeling like shit right now really want sleep...
# 28               1               goodbye exams hello alcohol tonight
# 29               0  didn realize was that deep geez give girl warn...
# ...            ...                                                ...
# 1048538          0                                      missing bito
# 1048540          0                          missing boyfriend lot ugh
# 1048541          0  missing boyfriend gonna crazy this just the fi...
# 1048542          0                      missing boyfriend love honey
# 1048543          0  missing boyfriend insanely sleeping alone and ...
# 1048544          0  missing boyfriend tony see you soon babe you c...
# 1048545          0      missing boy poetry concert tonight hate that
# 1048546          0          missing boys touch and trying not freeze
# 1048548          0                      missing bundle brilliant fun
# 1048549          0                        missing butterflies always
# 1048550          0                                       missing cat
# 1048551          0  missing cats much right now relocating hard ha...
# 1048552          0                       missing comcast hate direct
# 1048553          0                                   missing corbear
# 1048554          0                         missing dad brother today
# 1048556          1  missing daddio and laughing with him get all f...
# 1048557          0  missing daddy this weekend still miss him each...
# 1048558          0                           missing daddy today rip
# 1048559          0  missing daddy today some days feel further awa...
# 1048560          0                                     missing daddy
# 1048561          0              missing daily dose scrabble facebook
# 1048562          0  missing dear amandafriends all alone fixing po...
# 1048563          0  missing dearest love much learning for history...
# 1048564          0        missing dude back him days byebye michigan
# 1048565          0  missing fam want see before too late time grow...
# 1048567          0                            missing family the usa
# 1048568          0                       missing family lots tonight
# 1048569          0                                    missing fiance
# 1048570          0        missing fiancee sooo badly love you baybay
# 1048572          0  missing friend and cousin two months passed qu...
#
#          word count                                             tokens
# 0                 4                            [sad, for, apl, friend]
# 1                 5                  [missed, the, new, moon, trailer]
# 2                 3                                [omg, its, already]
# 3                15  [omgaga, sooo, gunna, cry, been, this, dentist...
# 4                 2                                  [think, cheating]
# 5                 4                           [just, worry, too, much]
# 6                 2                [juuuuuuuuuuuuuuuuussssst, chillin]
# 7                 5            [sunny, again, work, tomorrow, tonight]
# 8                 6            [handed, uniform, today, miss, already]
# 9                 5                       [hmmmm, wonder, how, number]
# 10                4                     [must, think, about, positive]
# 11                9  [thanks, all, the, haters, face, all, day, 112...
# 12                5                  [this, weekend, has, sucked, far]
# 13                5              [isnt, showing, australia, any, more]
# 14                3                                       [thats, win]
# 15                6                 [this, the, way, feel, right, now]
# 16                9  [awhhe, man, completely, useless, now, funny, ...
# 17                9  [feeling, strangely, fine, now, gonna, listen,...
# 18                6            [huge, roll, thunder, just, now, scary]
# 19               17  [just, cut, beard, off, only, been, growing, f...
# 20                4                           [very, sad, about, iran]
# 21                2                                   [wompppp, wompp]
# 22               19  [the, only, one, who, can, see, this, cause, o...
# 23               18  [sad, level, was, writing, massive, blog, twee...
# 24               15  [headed, hospitol, had, pull, out, the, golf, ...
# 25                7         [boring, whats, wrong, with, please, tell]
# 26               15  [can, bothered, wish, could, spend, the, rest,...
# 27               17  [feeeling, like, shit, right, now, really, wan...
# 28                5          [goodbye, exams, hello, alcohol, tonight]
# 29               10  [didn, realize, was, that, deep, geez, give, g...
# ...             ...                                                ...
# 1048538           2                                    [missing, bito]
# 1048540           4                     [missing, boyfriend, lot, ugh]
# 1048541           9  [missing, boyfriend, gonna, crazy, this, just,...
# 1048542           4                  [missing, boyfriend, love, honey]
# 1048543           7  [missing, boyfriend, insanely, sleeping, alone...
# 1048544          13  [missing, boyfriend, tony, see, soon, babe, ca...
# 1048545           7  [missing, boy, poetry, concert, tonight, hate,...
# 1048546           7   [missing, boys, touch, and, trying, not, freeze]
# 1048548           4                  [missing, bundle, brilliant, fun]
# 1048549           3                     [missing, butterflies, always]
# 1048550           2                                     [missing, cat]
# 1048551          10  [missing, cats, much, right, now, relocating, ...
# 1048552           4                   [missing, comcast, hate, direct]
# 1048553           2                                 [missing, corbear]
# 1048554           4                     [missing, dad, brother, today]
# 1048556          15  [missing, daddio, and, laughing, with, get, al...
# 1048557          11  [missing, daddy, this, weekend, still, miss, e...
# 1048558           4                       [missing, daddy, today, rip]
# 1048559          10  [missing, daddy, today, some, days, feel, furt...
# 1048560           2                                   [missing, daddy]
# 1048561           5         [missing, daily, dose, scrabble, facebook]
# 1048562           9  [missing, dear, amandafriends, all, alone, fix...
# 1048563           8  [missing, dearest, love, much, learning, for, ...
# 1048564           7      [missing, dude, back, days, byebye, michigan]
# 1048565          10  [missing, fam, want, see, before, too, late, t...
# 1048567           4                        [missing, family, the, usa]
# 1048568           4                   [missing, family, lots, tonight]
# 1048569           2                                  [missing, fiance]
# 1048570           7      [missing, fiancee, sooo, badly, love, baybay]
# 1048572           8  [missing, friend, and, cousin, two, months, pa...
#
# [993412 rows x 4 columns]

# %%
# split sentences to get individual words
all_words = []
for line in tweetsdf['tokens']: # try 'tokens'
    all_words.extend(line)
    
# create a word frequency dictionary
wordfreq = Counter(all_words)
wordfreq
# Out:
# Counter({'sad': 17309,
#          'for': 135410,
#          'apl': 2,
#          'friend': 7401,
#          'missed': 7346,
#          'the': 326745,
#          'new': 24654,
#          'moon': 1515,
#          'trailer': 772,
#          'omg': 5762,
#          'its': 29511,
#          'already': 9740,
#          'omgaga': 1,
#          'sooo': 3513,
#          'gunna': 749,
#          'cry': 2834,
#          'been': 23350,
#          'this': 54694,
#          'dentist': 760,
#          'since': 6289,
#          'was': 69490,
#          'suposed': 17,
#          'just': 88010,
#          'get': 53522,
#          'crown': 97,
#          'put': 5505,
#          '30mins': 54,
#          'think': 29263,
#          'cheating': 146,
#          'worry': 1919,
#          'too': 46495,
#          'much': 23860,
#          'juuuuuuuuuuuuuuuuussssst': 1,
#          'chillin': 1145,
#          'sunny': 2508,
#          'again': 18106,
#          'work': 36342,
#          'tomorrow': 19096,
#          'tonight': 14638,
#          'handed': 156,
#          'uniform': 106,
#          'today': 36614,
#          'miss': 23473,
#          'hmmmm': 345,
#          'wonder': 1849,
#          'how': 31742,
#          'number': 1577,
#          'must': 5716,
#          'about': 34308,
#          'positive': 779,
#          'thanks': 26888,
#          'all': 53135,
#          'haters': 201,
#          'face': 3499,
#          'day': 49042,
#          '112': 24,
#          '102': 93,
#          'weekend': 10862,
#          'has': 19679,
#          'sucked': 501,
#          'far': 4973,
#          'isnt': 1215,
#          'showing': 762,
#          'australia': 1032,
#          'any': 10763,
#          'more': 23698,
#          'thats': 7108,
#          'win': 3982,
#          'way': 14645,
#          'feel': 19593,
#          'right': 18338,
#          'now': 57017,
#          'awhhe': 1,
#          'man': 9237,
#          'completely': 1212,
#          'useless': 288,
#          'funny': 5318,
#          'can': 64172,
#          'twitter': 19412,
#          'feeling': 9171,
#          'strangely': 79,
#          'fine': 3479,
#          'gonna': 15031,
#          'listen': 2375,
#          'some': 29257,
#          'semisonic': 1,
#          'celebrate': 593,
#          'huge': 1792,
#          'roll': 790,
#          'thunder': 558,
#          'scary': 1304,
#          'cut': 2235,
#          'beard': 147,
#          'off': 19230,
#          'only': 18107,
#          'growing': 466,
#          'well': 28012,
#          'over': 14239,
#          'year': 7276,
#          'start': 6278,
#          'happy': 16803,
#          'meantime': 88,
#          'very': 17340,
#          'iran': 353,
#          'wompppp': 1,
#          'wompp': 1,
#          'one': 35807,
#          'who': 11434,
#          'see': 32308,
#          'cause': 4872,
#          'else': 3598,
#          'following': 4193,
#          'because': 9302,
#          'pretty': 8401,
#          'awesome': 12713,
#          'level': 562,
#          'writing': 1823,
#          'massive': 511,
#          'blog': 3399,
#          'tweet': 8141,
#          'myspace': 1824,
#          'and': 193620,
#          'comp': 570,
#          'shut': 958,
#          'down': 11396,
#          'lost': 6493,
#          'lays': 23,
#          'fetal': 9,
#          'position': 202,
#          'headed': 1179,
#          'hospitol': 2,
#          'had': 33419,
#          'pull': 531,
#          'out': 50743,
#          'golf': 493,
#          'tourny': 12,
#          '3rd': 765,
#          'place': 4234,
#          'ripped': 176,
#          'something': 9568,
#          'yeah': 17334,
#          'that': 119231,
#          'boring': 2464,
#          'whats': 1836,
#          'wrong': 4065,
#          'with': 71059,
#          'please': 10028,
#          'tell': 7516,
#          'bothered': 346,
#          'wish': 18452,
#          'could': 15083,
#          'spend': 1573,
#          'rest': 3324,
#          'life': 9688,
#          'sat': 1590,
#          'here': 25672,
#          'going': 40795,
#          'gigs': 211,
#          'seriously': 2715,
#          'feeeling': 14,
#          'like': 53689,
#          'shit': 4384,
#          'really': 31856,
#          'want': 27606,
#          'sleep': 15689,
#          'but': 92041,
#          'nooo': 661,
#          'have': 100728,
#          'hours': 7532,
#          'dancing': 979,
#          'art': 1109,
#          'assignment': 410,
#          'finish': 2187,
#          'goodbye': 1180,
#          'exams': 2287,
#          'hello': 3930,
#          'alcohol': 449,
#          'didn': 14651,
#          'realize': 679,
#          'deep': 615,
#          'geez': 309,
#          'give': 6024,
#          'girl': 7182,
#          'warning': 256,
#          'atleast': 458,
#          'hate': 12615,
#          'when': 27077,
#          'athlete': 27,
#          'appears': 211,
#          'tear': 497,
#          'acl': 14,
#          'live': 7206,
#          'television': 128,
#          'guys': 9815,
#          'wearing': 1030,
#          'skinny': 238,
#          'jeans': 447,
#          'cute': 5389,
#          'sweater': 111,
#          'heels': 322,
#          'not': 69493,
#          'sure': 11322,
#          'what': 38145,
#          'are': 52953,
#          'doing': 10952,
#          'meet': 3887,
#          'meat': 337,
#          'horsie': 6,
#          'moving': 1784,
#          'saturday': 3423,
#          'morning': 19071,
#          'need': 23118,
#          'days': 11644,
#          'week': 13330,
#          'dont': 12598,
#          'room': 3720,
#          'sick': 8744,
#          'wardrobe': 100,
#          'cant': 11349,
#          'waiit': 10,
#          'till': 4781,
#          'walk': 2361,
#          'yay': 6945,
#          'sox': 186,
#          'floyd': 44,
#          'great': 23074,
#          'relievers': 5,
#          'scolding': 9,
#          'times': 5050,
#          'million': 591,
#          'uploading': 346,
#          'pictures': 1898,
#          'friendster': 65,
#          'type': 1110,
#          'spaz': 31,
#          'downloads': 110,
#          'virus': 300,
#          'brother': 2228,
#          'msn': 866,
#          'fucked': 544,
#          'forever': 1607,
#          'fightiin': 1,
#          'wiit': 4,
#          'babes': 305,
#          'wrote': 832,
#          'last': 22009,
#          'got': 40768,
#          'call': 5749,
#          'from': 36306,
#          'someone': 6689,
#          'york': 677,
#          'office': 2924,
#          'enough': 4574,
#          'said': 6749,
#          'even': 12963,
#          'say': 11841,
#          'anyways': 991,
#          'chris': 976,
#          'cornell': 14,
#          'chicago': 921,
#          'health': 482,
#          'class': 3461,
#          'joke': 902,
#          'show': 10901,
#          'makes': 6265,
#          'look': 9403,
#          'muslims': 5,
#          'reality': 583,
#          'time': 35257,
#          'low': 1058,
#          'shall': 1485,
#          'motivation': 261,
#          'entertainment': 203,
#          'complained': 43,
#          'properly': 471,
#          'experimental': 17,
#          'should': 15410,
#          'experiment': 111,
#          'melody': 74,
#          'another': 9040,
#          'lakers': 1076,
#          'neither': 584,
#          'magic': 978,
#          'nor': 278,
#          'fun': 18825,
#          'baddest': 9,
#          'eveer': 4,
#          'bathroom': 427,
#          'clean': 1705,
#          'enjoyable': 154,
#          'tasks': 93,
#          'boom': 382,
#          'pow': 117,
#          'proud': 1480,
#          'congrats': 2955,
#          'helio': 8,
#          'though': 17106,
#          'david': 1641,
#          'hospitalized': 11,
#          'five': 792,
#          'end': 4827,
#          'july': 1716,
#          'palatine': 3,
#          'tonsils': 40,
#          'will': 34809,
#          'probably': 4583,
#          'never': 12290,
#          'katie': 402,
#          'concert': 2892,
#          'friends': 8708,
#          'leaving': 3303,
#          'stupid': 3637,
#          'love': 45104,
#          'mom': 5284,
#          'hug': 1535,
#          'harry': 845,
#          'sunday': 4702,
#          'happiness': 416,
#          'hand': 1747,
#          'quilting': 9,
#          'then': 22024,
#          'leysh': 1,
#          't9ar5': 1,
#          'always': 10615,
#          'bend': 76,
#          'backwards': 100,
#          'sooooon': 38,
#          'cody': 105,
#          'booo': 483,
#          'haven': 6082,
#          'seen': 4361,
#          'foreverr': 11,
#          'allergies': 468,
#          'hair': 4846,
#          'taking': 3076,
#          'public': 626,
#          'poll': 90,
#          'hurts': 3149,
#          'earl': 102,
#          'jersey': 438,
#          'first': 10603,
#          'hour': 4301,
#          'sytycd': 98,
#          'night': 25371,
#          'find': 9197,
#          'online': 2919,
#          'fix': 1473,
#          'thought': 7834,
#          'become': 848,
#          'second': 1966,
#          'choice': 969,
#          'may': 5480,
#          'friendly': 392,
#          'lol': 45882,
#          'manuel': 7,
#          'basil': 48,
#          'plant': 231,
#          'wanna': 10748,
#          'home': 23843,
#          'church': 1998,
#          'wht': 179,
#          'they': 30528,
#          'make': 16989,
#          'own': 3365,
#          'pizza': 1376,
#          '120gb': 6,
#          'harddrive': 27,
#          'inch': 134,
#          'guitar': 1103,
#          'anyonefeeling': 1,
#          'generous': 80,
#          'miley': 1733,
#          'tour': 2397,
#          'wanted': 5299,
#          'mean': 5555,
#          'kid': 1448,
#          'through': 4377,
#          'popsicle': 42,
#          'stick': 867,
#          'head': 5016,
#          'fly': 1259,
#          'away': 7601,
#          'those': 7182,
#          'squirrels': 46,
#          'slow': 1598,
#          'tix': 546,
#          'send': 3947,
#          'sunshine': 1600,
#          'northern': 128,
#          'ireland': 417,
#          'swimming': 829,
#          'beach': 3427,
#          'would': 20066,
#          'happier': 242,
#          'walls': 149,
#          'bedroom': 282,
#          'were': 12872,
#          'painted': 145,
#          'white': 1547,
#          'idk': 1804,
#          'wat': 983,
#          'trust': 807,
#          'sorry': 19238,
#          'pain': 2727,
#          'caused': 121,
#          'nebody': 2,
#          'ima': 857,
#          'take': 11389,
#          'dis': 339,
#          'straighten': 72,
#          'luv': 1714,
#          'yall': 858,
#          'finding': 860,
#          'intercept': 7,
#          'slope': 17,
#          'banging': 81,
#          'against': 811,
#          'wall': 675,
#          'math': 942,
#          'brain': 904,
#          'heads': 458,
#          'come': 17380,
#          'save': 1410,
#          'bed': 12247,
#          'cough': 743,
#          'cab': 288,
#          'airport': 1253,
#          'christy': 27,
#          'case': 1516,
#          'emo': 276,
#          'camp': 1000,
#          'wee': 524,
#          'bit': 7449,
#          'alr': 34,
#          'bringing': 392,
#          'human': 465,
#          'rights': 125,
#          'watch': 9948,
#          'world': 5622,
#          'report': 606,
#          '2009': 649,
#          'hope': 25201,
#          'jin': 18,
#          'jonas': 1712,
#          'almost': 4902,
#          'jus': 1397,
#          'hom': 21,
#          'tda': 3,
#          'funeral': 302,
#          'cried': 887,
#          'grandpa': 261,
#          'smile': 2046,
#          'cuz': 3543,
#          'zahra': 2,
#          'whom': 116,
#          'graduated': 249,
#          'longest': 301,
#          'ever': 8004,
#          'ugh': 3511,
#          'momacita': 1,
#          'won': 8778,
#          'let': 10616,
#          'bball': 106,
#          'game': 5703,
#          'grrr': 640,
#          'says': 2514,
#          'phone': 7898,
#          'immediately': 170,
#          'mobile': 893,
#          'paying': 500,
#          'car': 5146,
#          'stolen': 289,
#          'mother': 2230,
#          'pose': 100,
#          'hang': 2325,
#          'girls': 3299,
#          '2day': 1399,
#          '2moro': 329,
#          'movie': 7212,
#          'rats': 76,
#          'plan': 1881,
#          'guess': 7747,
#          'means': 2446,
#          'two': 6284,
#          'presentations': 64,
#          'pavel': 6,
#          'tigersfan': 2,
#          'cool': 10313,
#          'thank': 11149,
#          'pleased': 353,
#          'guna': 131,
#          'soon': 12228,
#          'talkin': 380,
#          'safina': 11,
#          'lose': 1245,
#          'rip': 662,
#          'eddings': 30,
#          'rose': 280,
#          'ood': 4,
#          'back': 35348,
#          'xmas': 120,
#          'special': 1740,
#          'damn': 7840,
#          'half': 3486,
#          'sannesias': 1,
#          'aww': 6705,
#          'neighbor': 242,
#          'status': 551,
#          'next': 12239,
#          'husband': 973,
#          'overdosed': 7,
#          'daily': 613,
#          'dose': 141,
#          'haterade': 4,
#          'definition': 97,
#          'throwbie': 1,
#          'editors': 19,
#          'reviewed': 37,
#          'entry': 234,
#          'decided': 1419,
#          'publish': 82,
#          'help': 7470,
#          'explains': 124,
#          'alot': 1279,
#          'there': 31495,
#          'heathers': 19,
#          'sequel': 81,
#          'winona4ever': 1,
#          'better': 15947,
#          'fuck': 3108,
#          'told': 3170,
#          'drink': 2432,
#          'gave': 1940,
#          'porter': 18,
#          'obs': 2,
#          'stout': 21,
#          'brought': 794,
#          'neighbors': 242,
#          'trae': 6,
#          'sweet': 4742,
#          'bought': 2892,
#          'baithing': 1,
#          'suit': 325,
#          'wove': 4,
#          'true': 4071,
#          'highly': 301,
#          'subjective': 12,
#          'tombre': 1,
#          'actually': 7176,
#          'favorite': 2608,
#          'character': 445,
#          'book': 3706,
#          'rishabh': 1,
#          'knw': 253,
#          'whyy': 67,
#          'waahhh': 6,
#          'getting': 15359,
#          'hub': 75,
#          'standing': 366,
#          'pouring': 313,
#          'rain': 5384,
#          'sitting': 1957,
#          'top': 2211,
#          'summer': 6768,
#          'sucks': 6637,
#          'went': 7610,
#          'dog': 2866,
#          'vets': 64,
#          'theyve': 24,
#          'stitched': 11,
#          'ear': 680,
#          'charged': 126,
#          'still': 25690,
#          'bleeds': 13,
#          'waterfall': 28,
#          'everytime': 586,
#          'moves': 195,
#          'why': 14712,
#          'where': 9639,
#          'picture': 3157,
#          'naked': 379,
#          'aren': 2001,
#          'trains': 145,
#          'manchester': 356,
#          'people': 12857,
#          'picky': 72,
#          'dice': 71,
#          'what\x8b¨«': 9,
#          'obsolete': 15,
#          'asp': 50,
#          'wide': 460,
#          'awake': 2664,
#          'awful': 1199,
#          'weather': 5559,
#          'stinks': 263,
#          'kristis': 1,
#          'comin': 407,
#          'moe': 54,
#          'mmmaybe': 1,
#          'stranger': 183,
#          'frank': 188,
#          'lampard': 8,
#          'urself': 178,
#          'gay': 1057,
#          '2007': 111,
#          'panel': 109,
#          'normal': 1033,
#          'started': 2966,
#          'brighten': 78,
#          'bad': 17416,
#          'anything': 5829,
#          'boyle': 290,
#          'didnt': 4669,
#          'diversity': 466,
#          'good': 59939,
#          'congratz': 62,
#          'believe': 5116,
#          'goooood': 173,
#          'timessss': 7,
#          'graduate': 346,
#          '093': 2,
#          'vandals': 3,
#          'paint': 476,
#          'swastikas': 2,
#          'author': 135,
#          'lesbian': 93,
#          'story': 1952,
#          'naples': 13,
#          'news': 3523,
#          'unknown': 103,
#          'error': 471,
#          'occured': 13,
#          'iphone': 4456,
#          'fail': 1994,
#          'experts': 46,
#          'homers': 2,
#          'predict': 51,
#          'eagles': 38,
#          'giants': 89,
#          'php': 225,
#          '49343': 1,
#          'know': 38711,
#          'hungry': 2474,
#          'lets': 1718,
#          'outside': 3759,
#          'balcony': 162,
#          'eat': 4735,
#          'driving': 1865,
#          'mad': 2523,
#          'men': 1031,
#          'female': 306,
#          'internet': 2859,
#          'entrepreneur': 20,
#          'starting': 2183,
#          'business': 1310,
#          'women': 710,
#          'http': 1645,
#          'tinyurl': 51,
#          'com': 4684,
#          'truth': 520,
#          'hiding': 305,
#          'eyes': 2114,
#          'paramore': 231,
#          '\x8b¨«': 2372,
#          'decode': 26,
#          '5ytke': 1,
#          'try': 7524,
#          'turn': 2012,
#          'inside': 1365,
#          'admit': 498,
#          'literally': 559,
#          'coldplay': 148,
#          'tears': 653,
#          'kids': 3787,
#          'break': 2682,
#          'their': 5647,
#          'dads': 430,
#          'sighs': 187,
#          'unsure': 67,
#          'annoyed': 646,
#          'via': 1707,
#          'designed': 119,
#          'gallery': 135,
#          'exhibition': 70,
#          'postcards': 31,
#          'mailers': 3,
#          'extinct': 16,
#          'nyt': 106,
#          'beautifulylost': 3,
#          'cries': 284,
#          'potter': 604,
#          'comes': 2252,
#          'vietnam': 57,
#          '11th': 141,
#          'hummin': 2,
#          'money': 3976,
#          'mouth': 785,
#          'headin': 189,
#          'cheers': 986,
#          'sigh': 2110,
#          'doesn': 6874,
#          'stalker': 206,
#          'divorce': 188,
#          'move': 2474,
#          'trinity': 30,
#          'lookin': 642,
#          'around': 5994,
#          'don': 35414,
#          'reason': 2348,
#          'atm': 681,
#          'little': 10908,
#          'aiqht': 1,
#          'goodniqht': 1,
#          'tri': 48,
#          'neena': 3,
#          'malcolm': 31,
#          'chaise': 4,
#          'jlew': 1,
#          'atl': 534,
#          '333': 337,
#          'triiiiiii': 1,
#          'ily': 678,
#          'dies': 243,
#          'laughter': 132,
#          'wantt': 5,
#          'hiim': 8,
#          'soo': 3075,
#          'badd': 57,
#          'watching': 8857,
#          'shopping': 2771,
#          'trent': 84,
#          'hopefully': 3854,
#          'best': 10566,
#          'weird': 2236,
#          'encounters': 19,
#          'many': 5681,
#          'homeless': 116,
#          'creeps': 35,
#          'rained': 351,
#          'truck': 432,
#          'race': 788,
#          'worse': 1761,
#          'same': 8167,
#          'confusing': 335,
#          'hot': 6699,
#          'choco': 71,
#          'shirt': 1506,
#          'panties': 56,
#          'celulite': 1,
#          'north': 640,
#          'due': 1618,
#          'body': 1513,
#          'line': 1580,
#          'missing': 4632,
#          'design': 826,
#          'council': 86,
#          'tech': 501,
#          'transfer': 152,
#          'event': 973,
#          'everything': 4971,
#          'hard': 6308,
#          'bueno': 178,
#          'bye': 2369,
#          'scoobs': 1,
#          'amazing': 7823,
#          'twits': 248,
#          'canaveral': 3,
#          'national': 396,
#          'seashore': 5,
#          'progressing': 15,
#          'production': 150,
#          'department': 105,
#          'uprizing': 1,
#          'priority': 80,
#          'nodding': 26,
#          'beats': 271,
#          'reach': 427,
#          'taylorrhicks': 1,
#          'enjoy': 5594,
#          'venue': 197,
#          'shine': 247,
#          'everywhere': 719,
#          'everyone': 8522,
#          'train': 1321,
#          'crash': 524,
#          'thestreetforce': 1,
#          'weeks': 4077,
#          'child': 590,
#          'before': 8302,
#          'nancy': 80,
#          'grac': 2,
#          'woody': 49,
#          'woodpecker': 14,
#          '\x83': 2681,
#          'barber': 28,
#          'seville': 4,
#          'wishing': 1066,
#          '®': 790,
#          '7g6r0': 1,
#          'staying': 1044,
#          'drexel': 2,
#          'fabulous': 768,
#          'university': 278,
#          'happened': 2372,
#          'angels': 368,
#          'demons': 243,
#          'lions': 127,
#          'tigers': 53,
#          'bears': 174,
#          'minimizes': 1,
#          'impact': 67,
#          'dibs': 25,
#          'voltron': 3,
#          'arm': 604,
#          'leg': 780,
#          'wait': 14983,
#          'manners': 27,
#          'saw': 6896,
#          'mum': 1801,
#          'fat': 1129,
#          'asses': 76,
#          'nai': 13,
#          'three': 1736,
#          'external': 133,
#          'monitors': 34,
#          'laptop': 2071,
#          'win7rc': 1,
#          '1920x1080': 1,
#          '1280x1024': 3,
#          'facebook': 2758,
#          'copic': 1,
#          'marker': 36,
#          'maybe': 8764,
#          'later': 6287,
#          'californians': 3,
#          'making': 5081,
#          'fettucini': 5,
#          'garlic': 157,
#          'bread': 619,
#          'bday': 1753,
#          'once': 3344,
#          'pants': 699,
#          'ironically': 54,
#          'job': 5502,
#          'fml': 981,
#          'sweep': 57,
#          'haha': 24501,
#          'gr8': 468,
#          'science': 657,
#          'cartoons': 108,
#          'edinburgh': 162,
#          'fringe': 117,
#          'monies': 82,
#          'btw': 3949,
#          'elliott': 32,
#          'blame': 693,
#          'intrusion': 4,
#          'school': 11240,
#          'done': 9592,
#          'short': 1845,
#          'stack': 182,
#          'thing': 9929,
#          'which': 4931,
#          'latter': 84,
#          'store': 2024,
#          'thinking': 4364,
#          'less': 2283,
#          'than': 9580,
#          'chance': 1993,
#          'hedo': 7,
#          'stays': 220,
#          'orlando': 438,
#          'wud': 292,
#          'beautiful': 5277,
#          'plc': 11,
#          'outer': 44,
#          'servers': 175,
#          'backup': 225,
#          'experience': 869,
#          'problems': 1095,
#          'delay': 220,
#          'yes': 13703,
#          'gentle': 77,
#          'breeze': 157,
#          'blown': 171,
#          'throug': 2,
#          '7s7mn': 1,
#          'morrea': 1,
#          'joseph': 88,
#          'vale': 16,
#          'future': 1072,
#          'rooooooooomies': 1,
#          'nyc': 1135,
#          'holler': 45,
#          'cheese': 1160,
#          'burgers': 174,
#          'lmbo': 31,
#          'nothing': 6403,
#          'kind': 3461,
#          'sort': 1038,
#          'pick': 1844,
#          'flowers': 506,
#          'teacher': 642,
#          'jealous': 3121,
#          'without': 4561,
#          'having': 10668,
#          'hospital': 1224,
#          'them': 17877,
#          'talvez': 2,
#          'seja': 4,
#          '¦nfase': 1,
#          'cifra': 1,
#          'mas': 120,
#          'atençõç\x9c': 1,
#          'security': 293,
#          'chain': 161,
#          'strong': 739,
#          'weakest': 11,
#          'link': 3172,
#          'youtube': 2169,
#          'account': 1890,
#          'suspended': 176,
#          'single': 1220,
#          'ladies': 884,
#          'dance': 2083,
#          'sold': 1286,
#          'hoping': 2613,
#          'nervous': 775,
#          'aim': 536,
#          'talk': 5662,
#          '1000': 320,
#          'followers': 3274,
#          'grocery': 374,
#          'blasted': 47,
#          'oldies': 47,
#          'sugar': 566,
#          'ray': 357,
#          'does': 6686,
#          'kashrut': 1,
#          'convo': 234,
#          'keep': 7957,
#          'kosher': 17,
#          'roomies': 62,
#          'catholic': 59,
#          'pork': 157,
#          'loin': 3,
#          'fridge': 312,
#          'isn': 4924,
#          'bitches': 285,
#          'wake': 2530,
#          'early': 6551,
#          'opera': 219,
#          'kay': 280,
#          'immune': 55,
#          'dentists': 53,
#          'drills': 9,
#          'etc': 1133,
#          'bother': 374,
#          'gum': 145,
#          'lift': 177,
#          'surgery': 566,
#          'tho': 5686,
#          'eek': 196,
#          'tonite': 720,
#          'hates': 1352,
#          'bebot': 2,
#          'app': 1256,
#          'bhai': 16,
#          'used': 3741,
#          'arre': 12,
#          'kuch': 16,
#          'kam': 18,
#          'chilling': 587,
#          'spanking': 29,
#          'blackberry': 921,
#          'unlimited': 124,
#          'every': 4440,
#          'pop': 754,
#          'quite': 3226,
#          'active': 215,
#          'shame': 1684,
#          'mamma': 58,
#          'mia': 309,
#          'horny': 206,
#          'island': 688,
#          'letting': 680,
#          'check': 5834,
#          'eureka': 16,
#          'knowledge': 177,
#          'referring': 170,
#          'hey': 15022,
#          'thx': 1899,
#          'ttyl': 255,
#          'sowwy': 121,
#          'mothers': 1101,
#          'knew': 2250,
#          'sharepoint': 42,
#          'written': 407,
#          'interns': 42,
#          'practising': 24,
#          ...})

# %% [markdown]
# ### 7. Vectorization and Transformation of Count Matrix

# %%
# vetorize
bow_transformer = CountVectorizer(analyzer=text_process).fit(tweetsdf['Sentiment Text'])
# print total number of vocab words
print(len(bow_transformer.vocabulary_))
# Out:
# 216196

# %%
#entire word vocabulary 
bow_transformer.vocabulary_
# Out:
# {'sad': 161838,
#  'for': 72879,
#  'apl': 16572,
#  'friend': 74444,
#  'missed': 124832,
#  'the': 186192,
#  'new': 132287,
#  'moon': 126642,
#  'trailer': 190828,
#  'omg': 137628,
#  'its': 98856,
#  'already': 13746,
#  'omgaga': 137635,
#  'sooo': 174033,
#  'gunna': 83504,
#  'cry': 49027,
#  'been': 24962,
#  'this': 187042,
#  'dentist': 53687,
#  'since': 170146,
#  'was': 202512,
#  'suposed': 180897,
#  'just': 103191,
#  'get': 78249,
#  'crown': 48815,
#  'put': 151901,
#  '30mins': 3319,
#  'think': 186953,
#  'cheating': 39682,
#  'worry': 207952,
#  'too': 189792,
#  'much': 128200,
#  'juuuuuuuuuuuuuuuuussssst': 103310,
#  'chillin': 40630,
#  'sunny': 180502,
#  'again': 11267,
#  'work': 207698,
#  'tomorrow': 189538,
#  'tonight': 189687,
#  'handed': 85347,
#  'uniform': 196749,
#  'today': 189090,
#  'miss': 124808,
#  'hmmmm': 89750,
#  'wonder': 207097,
#  'how': 91759,
#  'number': 135440,
#  'must': 129082,
#  'about': 9222,
#  'positive': 148227,
#  'thanks': 185953,
#  'all': 13264,
#  'haters': 86365,
#  'face': 67574,
#  'day': 51772,
#  '112': 639,
#  '102': 426,
#  'weekend': 203602,
#  'has': 86195,
#  'sucked': 179648,
#  'far': 68490,
#  'isnt': 98512,
#  'showing': 168946,
#  'australia': 19796,
#  'any': 16162,
#  'more': 126863,
#  'thats': 186131,
#  'win': 206086,
#  'way': 202949,
#  'feel': 69398,
#  'right': 158755,
#  'now': 135069,
#  'awhhe': 20512,
#  'man': 118567,
#  'completely': 44879,
#  'useless': 198037,
#  'funny': 75644,
#  'can': 36257,
#  'twitter': 194184,
#  'feeling': 69418,
#  'strangely': 178422,
#  'fine': 70678,
#  'gonna': 80482,
#  'listen': 113145,
#  'some': 173622,
#  'semisonic': 165828,
#  'celebrate': 38324,
#  'huge': 92251,
#  'roll': 159852,
#  'thunder': 187622,
#  'scary': 163850,
#  'cut': 49820,
#  'beard': 24315,
#  'off': 136624,
#  'only': 138015,
#  'growing': 82779,
#  'well': 203902,
#  'over': 139861,
#  'year': 210355,
#  'start': 177110,
#  'happy': 85753,
#  'meantime': 121406,
#  'very': 199630,
#  'iran': 98090,
#  'wompppp': 207076,
#  'wompp': 207075,
#  'one': 137870,
#  'who': 205205,
#  'see': 165353,
#  'cause': 37885,
#  'else': 62717,
#  'following': 72528,
#  'because': 24600,
#  'pretty': 149626,
#  'awesome': 20409,
#  'level': 111773,
#  'writing': 208379,
#  'massive': 120040,
#  'blog': 28815,
#  'tweet': 193239,
#  'myspace': 129676,
#  'and': 15001,
#  'comp': 44709,
#  'shut': 169202,
#  'down': 58326,
#  'lost': 115017,
#  'lays': 110570,
#  'fetal': 69882,
#  'position': 148219,
#  'headed': 87008,
#  'hospitol': 91379,
#  'had': 84395,
#  'pull': 151456,
#  'out': 139549,
#  'golf': 80383,
#  'tourny': 190475,
#  '3rd': 4004,
#  'place': 146068,
#  'ripped': 159001,
#  'something': 173723,
#  'yeah': 210304,
#  'that': 186087,
#  'boring': 30719,
#  'whats': 204599,
#  'wrong': 208432,
#  'with': 206548,
#  'please': 146468,
#  'tell': 184854,
#  'bothered': 30934,
#  'wish': 206455,
#  'could': 47233,
#  'spend': 175376,
#  'rest': 157667,
#  'life': 112218,
#  'sat': 163157,
#  'here': 88310,
#  'going': 80256,
#  'gigs': 78793,
#  'seriously': 166231,
#  'feeeling': 69378,
#  'like': 112479,
#  'shit': 168166,
#  'really': 154877,
#  'want': 202276,
#  'sleep': 171465,
#  'but': 34638,
#  'nooo': 134360,
#  'have': 86507,
#  'hours': 91633,
#  'dancing': 51004,
#  'art': 18028,
#  'assignment': 18783,
#  'finish': 70766,
#  'goodbye': 80552,
#  'exams': 66274,
#  'hello': 87955,
#  'alcohol': 12851,
#  'didn': 55076,
#  'realize': 154822,
#  'deep': 52760,
#  'geez': 77628,
#  'give': 79312,
#  'girl': 79092,
#  'warning': 202439,
#  'atleast': 19248,
#  'hate': 86329,
#  'when': 204781,
#  'athlete': 19186,
#  'appears': 16717,
#  'tear': 184295,
#  'acl': 9888,
#  'live': 113341,
#  'television': 184834,
#  'guys': 83770,
#  'wearing': 203152,
#  'skinny': 170949,
#  'jeans': 100535,
#  'cute': 49827,
#  'sweater': 181708,
#  'heels': 87596,
#  'not': 134766,
#  'sure': 181058,
#  'what': 204500,
#  'are': 17346,
#  'doing': 57317,
#  'meet': 121775,
#  'meat': 121433,
#  'horsie': 91326,
#  'moving': 127681,
#  'saturday': 163274,
#  'morning': 126996,
#  'need': 131413,
#  'days': 51852,
#  'week': 203585,
#  'dont': 57673,
#  'room': 160095,
#  'sick': 169413,
#  'wardrobe': 202373,
#  'cant': 36552,
#  'waiit': 201807,
#  'till': 188127,
#  'walk': 202008,
#  'yay': 210121,
#  'sox': 174799,
#  'floyd': 72007,
#  'great': 82081,
#  'relievers': 156604,
#  'scolding': 164415,
#  'times': 188232,
#  'million': 124019,
#  'uploading': 197608,
#  'pictures': 145214,
#  'friendster': 74489,
#  'type': 194994,
#  'spaz': 175098,
#  'downloads': 58375,
#  'virus': 200378,
#  'brother': 32906,
#  'msn': 127976,
#  'fucked': 75114,
#  'forever': 73016,
#  'fightiin': 70294,
#  'wiit': 205826,
#  'babes': 21374,
#  'wrote': 208459,
#  'last': 110044,
#  'got': 81201,
#  'call': 35891,
#  'from': 74723,
#  'someone': 173678,
#  'york': 211454,
#  'office': 136706,
#  'enough': 63875,
#  'said': 162105,
#  'even': 65646,
#  'say': 163505,
#  'anyways': 16320,
#  'chris': 41374,
#  'cornell': 46814,
#  'chicago': 40312,
#  'health': 87131,
#  'class': 42477,
#  'joke': 102054,
#  'show': 168889,
#  'makes': 118144,
#  'look': 114545,
#  'muslims': 129053,
#  'reality': 154812,
#  'time': 188178,
#  'low': 115584,
#  'shall': 166973,
#  'motivation': 127395,
#  'entertainment': 64006,
#  'complained': 44846,
#  'properly': 150618,
#  'experimental': 66862,
#  'should': 168825,
#  'experiment': 66861,
#  'melody': 122167,
#  'another': 15782,
#  'lakers': 109358,
#  'neither': 131708,
#  'magic': 117639,
#  'nor': 134513,
#  'fun': 75462,
#  'baddest': 21884,
#  'eveer': 65628,
#  'bathroom': 23592,
#  'clean': 42609,
#  'enjoyable': 63777,
#  'tasks': 183711,
#  'boom': 30270,
#  'pow': 148577,
#  'proud': 150783,
#  'congrats': 45563,
#  'helio': 87837,
#  'though': 187274,
#  'david': 51668,
#  'hospitalized': 91373,
#  'five': 71179,
#  'end': 63474,
#  'july': 102941,
#  'palatine': 141014,
#  'tonsils': 189765,
#  'will': 205958,
#  'probably': 150056,
#  'never': 132237,
#  'katie': 104450,
#  'concert': 45174,
#  'friends': 74475,
#  'leaving': 110914,
#  'stupid': 179171,
#  'love': 115218,
#  'mom': 126024,
#  'hug': 92248,
#  'harry': 86120,
#  'sunday': 180394,
#  'happiness': 85709,
#  'hand': 85320,
#  'quilting': 152866,
#  'then': 186489,
#  'leysh': 111879,
#  't9ar5': 182558,
#  'always': 13976,
#  'bend': 25587,
#  'backwards': 21808,
#  'sooooon': 174075,
#  'cody': 43650,
#  'booo': 30320,
#  'haven': 86529,
#  'seen': 165453,
#  'foreverr': 73025,
#  'allergies': 13338,
#  'hair': 84836,
#  'taking': 182988,
#  'public': 151240,
#  'poll': 147442,
#  'hurts': 92932,
#  'earl': 60673,
#  'jersey': 101027,
#  'first': 71008,
#  'hour': 91618,
#  'sytycd': 182467,
#  'night': 133117,
#  'find': 70650,
#  'online': 137994,
#  'fix': 71197,
#  'thought': 187283,
#  'become': 24669,
#  'second': 165244,
#  'choice': 41126,
#  'may': 120591,
#  'friendly': 74471,
#  'lol': 114140,
#  'manuel': 119043,
#  'basil': 23418,
#  'plant': 146205,
#  'wanna': 202218,
#  'home': 90380,
#  'church': 41686,
#  'wht': 205476,
#  'they': 186762,
#  'make': 118110,
#  'own': 140240,
#  'pizza': 145984,
#  '120gb': 755,
#  'harddrive': 85885,
#  'inch': 95770,
#  'guitar': 83349,
#  'anyonefeeling': 16243,
#  'generous': 77851,
#  'miley': 123877,
#  'tour': 190435,
#  'wanted': 202287,
#  'mean': 121366,
#  'kid': 105953,
#  'through': 187476,
#  'popsicle': 147930,
#  'stick': 177752,
#  'head': 86929,
#  'fly': 72131,
#  'away': 20325,
#  'those': 187261,
#  'squirrels': 176358,
#  'slow': 171873,
#  'tix': 188723,
#  'send': 165880,
#  'sunshine': 180544,
#  'northern': 134644,
#  'ireland': 98130,
#  'swimming': 181987,
#  'beach': 24191,
#  'would': 208067,
#  'happier': 85699,
#  'walls': 202100,
#  'bedroom': 24771,
#  'were': 204093,
#  'painted': 140904,
#  'white': 205094,
#  'idk': 94062,
#  'wat': 202635,
#  'trust': 192105,
#  'sorry': 174367,
#  'pain': 140863,
#  'caused': 37888,
#  'nebody': 131292,
#  'ima': 95023,
#  'take': 182939,
#  'dis': 55844,
#  'straighten': 178376,
#  'luv': 116418,
#  'yall': 209871,
#  'finding': 70667,
#  'intercept': 97285,
#  'slope': 171842,
#  'banging': 22765,
#  'against': 11286,
#  'wall': 202049,
#  'math': 120220,
#  'brain': 31556,
#  'heads': 87080,
#  'come': 44307,
#  'save': 163393,
#  'bed': 24694,
#  'cough': 47200,
#  'cab': 35362,
#  'airport': 12310,
#  'christy': 41481,
#  'case': 37441,
#  'emo': 63151,
#  'camp': 36180,
#  'wee': 203458,
#  'bit': 27735,
#  'alr': 13728,
#  'bringing': 32420,
#  'human': 92469,
#  'rights': 158785,
#  'watch': 202652,
#  'world': 207848,
#  'report': 157212,
#  '2009': 1919,
#  'hope': 91022,
#  'jin': 101480,
#  'jonas': 102147,
#  'almost': 13577,
#  'jus': 103165,
#  'hom': 90369,
#  'tda': 184148,
#  'funeral': 75529,
#  'cried': 48472,
#  'grandpa': 81784,
#  'smile': 172258,
#  'cuz': 49979,
#  'zahra': 212490,
#  'whom': 205289,
#  'graduated': 81561,
#  'longest': 114422,
#  'ever': 65701,
#  'ugh': 195423,
#  'momacita': 126026,
#  'won': 207083,
#  'let': 111663,
#  'bball': 23878,
#  'game': 76625,
#  'grrr': 82835,
#  'says': 163567,
#  'phone': 144688,
#  'immediately': 95246,
#  'mobile': 125582,
#  'paying': 142626,
#  'car': 36831,
#  'stolen': 178081,
#  'mother': 127307,
#  'pose': 148174,
#  'hang': 85451,
#  'girls': 79171,
#  '2day': 2705,
#  '2moro': 2931,
#  'movie': 127623,
#  'rats': 154272,
#  'plan': 146145,
#  'guess': 83215,
#  'means': 121401,
#  'two': 194704,
#  'presentations': 149462,
#  'pavel': 142542,
#  'tigersfan': 188000,
#  'cool': 46365,
#  'thank': 185899,
#  'pleased': 146471,
#  'guna': 83475,
#  'soon': 174005,
#  'talkin': 183107,
#  'safina': 162021,
#  'lose': 114971,
#  'rip': 158978,
#  'eddings': 61275,
#  'rose': 160242,
#  'ood': 138149,
#  'back': 21624,
#  'xmas': 209242,
#  'special': 175180,
#  'damn': 50872,
#  'half': 84992,
#  'sannesias': 162815,
#  'aww': 20656,
#  'neighbor': 131666,
#  'status': 177257,
#  'next': 132500,
#  'husband': 92968,
#  'overdosed': 139919,
#  'daily': 50653,
#  'dose': 58073,
#  'haterade': 86356,
#  'definition': 52964,
#  'throwbie': 187491,
#  'editors': 61375,
#  'reviewed': 158110,
#  'entry': 64094,
#  'decided': 52497,
#  'publish': 151262,
#  'help': 88052,
#  'explains': 66907,
#  'alot': 13665,
#  'there': 186585,
#  'heathers': 87307,
#  'sequel': 166110,
#  'winona4ever': 206308,
#  'better': 26335,
#  'fuck': 75101,
#  'told': 189310,
#  'drink': 58991,
#  'gave': 77187,
#  'porter': 148093,
#  'obs': 136193,
#  'stout': 178314,
#  'brought': 32928,
#  'neighbors': 131671,
#  'trae': 190783,
#  'sweet': 181795,
#  'bought': 31032,
#  'baithing': 22227,
#  'suit': 179968,
#  'wove': 208124,
#  'true': 192023,
#  'highly': 89027,
#  'subjective': 179379,
#  'tombre': 189411,
#  'actually': 10105,
#  'favorite': 68942,
#  'character': 39265,
#  'book': 30175,
#  'rishabh': 159041,
#  'knw': 107378,
#  'whyy': 205548,
#  'waahhh': 201498,
#  'getting': 78338,
#  'hub': 92131,
#  'standing': 176918,
#  'pouring': 148544,
#  'rain': 153592,
#  'sitting': 170567,
#  'top': 189990,
#  'summer': 180140,
#  'sucks': 179707,
#  'went': 204054,
#  'dog': 57192,
#  'vets': 199701,
#  'theyve': 186780,
#  'stitched': 177968,
#  'ear': 60640,
#  'charged': 39314,
#  'still': 177841,
#  'bleeds': 28453,
#  'waterfall': 202757,
#  'everytime': 65903,
#  'moves': 127617,
#  'why': 205525,
#  'where': 204815,
#  'picture': 145199,
#  'naked': 130319,
#  'aren': 17376,
#  'trains': 190870,
#  'manchester': 118643,
#  'people': 143476,
#  'picky': 145152,
#  'dice': 54953,
#  'what\x8b¨«': 204667,
#  'obsolete': 136243,
#  'asp': 18621,
#  'wide': 205628,
#  'awake': 20262,
#  'awful': 20493,
#  'weather': 203174,
#  'stinks': 177926,
#  'kristis': 108088,
#  'comin': 44451,
#  'moe': 125789,
#  'mmmaybe': 125377,
#  'stranger': 178424,
#  'frank': 73694,
#  'lampard': 109587,
#  'urself': 197942,
#  'gay': 77240,
#  '2007': 1917,
#  'panel': 141253,
#  'normal': 134579,
#  'started': 177116,
#  'brighten': 32320,
#  'bad': 21846,
#  'anything': 16276,
#  'boyle': 31311,
#  'didnt': 55083,
#  'diversity': 56644,
#  'good': 80532,
#  'congratz': 45597,
#  'believe': 25364,
#  'goooood': 80889,
#  'timessss': 188246,
#  'graduate': 81560,
#  '093': 229,
#  'vandals': 198809,
#  'paint': 140896,
#  'swastikas': 181662,
#  'author': 19830,
#  'lesbian': 111601,
#  'story': 178286,
#  'naples': 130591,
#  'news': 132385,
#  'unknown': 196888,
#  'error': 64712,
#  'occured': 136358,
#  'iphone': 97978,
#  'fail': 67848,
#  'experts': 66875,
#  'homers': 90488,
#  'predict': 149106,
#  'eagles': 60616,
#  'giants': 78669,
#  'php': 144889,
#  '49343': 4532,
#  'know': 107301,
#  'hungry': 92703,
#  'lets': 111696,
#  'outside': 139702,
#  'balcony': 22372,
#  'eat': 60903,
#  'driving': 59069,
#  'mad': 117326,
#  'men': 122308,
#  'female': 69631,
#  'internet': 97407,
#  'entrepreneur': 64078,
#  'starting': 177126,
#  'business': 34533,
#  'women': 207060,
#  'http': 92084,
#  'tinyurl': 188460,
#  'com': 44247,
#  'truth': 192123,
#  'hiding': 88948,
#  'eyes': 67289,
#  'paramore': 141625,
#  '\x8b¨«': 213632,
#  'decode': 52579,
#  '5ytke': 5540,
#  'try': 192165,
#  'turn': 192804,
#  'inside': 96912,
#  'admit': 10538,
#  'literally': 113229,
#  'coldplay': 43917,
#  'tears': 184313,
#  'kids': 106039,
#  'break': 31889,
#  'their': 186402,
#  'dads': 50534,
#  'sighs': 169660,
#  'unsure': 197290,
#  'annoyed': 15694,
#  'via': 199778,
#  'designed': 54122,
#  'gallery': 76547,
#  'exhibition': 66643,
#  'postcards': 148314,
#  'mailers': 117904,
#  'extinct': 67107,
#  'nyt': 135865,
#  'beautifulylost': 24476,
#  'cries': 48479,
#  'potter': 148482,
#  'comes': 44378,
#  'vietnam': 200060,
#  '11th': 725,
#  'hummin': 92551,
#  'money': 126246,
#  'mouth': 127569,
#  'headin': 87030,
#  'cheers': 39851,
#  'sigh': 169643,
#  'doesn': 57165,
#  'stalker': 176847,
#  'divorce': 56698,
#  'move': 127594,
#  'trinity': 191677,
#  'lookin': 114573,
#  'around': 17778,
#  'don': 57515,
#  'reason': 155005,
#  'atm': 19263,
#  'little': 113292,
#  'aiqht': 12215,
#  'goodniqht': 80692,
#  'tri': 191490,
#  'neena': 131531,
#  'malcolm': 118290,
#  'chaise': 38936,
#  'jlew': 101657,
#  'atl': 19226,
#  '333': 3463,
#  'triiiiiii': 191624,
#  'ily': 94960,
#  'dies': 55163,
#  'laughter': 110275,
#  'wantt': 202312,
#  'hiim': 89125,
#  'soo': 173982,
#  'badd': 21868,
#  'watching': 202687,
#  'shopping': 168665,
#  'trent': 191430,
#  'hopefully': 91039,
#  'best': 26085,
#  'weird': 203790,
#  'encounters': 63452,
#  'many': 119075,
#  'homeless': 90452,
#  'creeps': 48354,
#  'rained': 153620,
#  'truck': 192003,
#  'race': 153186,
#  'worse': 207967,
#  'same': 162470,
#  'confusing': 45496,
#  'hot': 91436,
#  'choco': 41067,
#  'shirt': 168145,
#  'panties': 141388,
#  'celulite': 38451,
#  'north': 134624,
#  'due': 59698,
#  'body': 29599,
#  'line': 112798,
#  'missing': 124869,
#  'design': 54116,
#  'council': 47290,
#  'tech': 184376,
#  'transfer': 190994,
#  'event': 65674,
#  'everything': 65878,
#  'hard': 85860,
#  'bueno': 33669,
#  'bye': 35102,
#  'scoobs': 164427,
#  'amazing': 14218,
#  'twits': 194091,
#  'canaveral': 36303,
#  'national': 130875,
#  'seashore': 165113,
#  'progressing': 150371,
#  'production': 150239,
#  'department': 53741,
#  'uprizing': 197673,
#  'priority': 149914,
#  'nodding': 133994,
#  'beats': 24414,
#  'reach': 154645,
#  'taylorrhicks': 183992,
#  'enjoy': 63776,
#  'venue': 199425,
#  'shine': 168016,
#  'everywhere': 65919,
#  'everyone': 65842,
#  'train': 190848,
#  'crash': 48038,
#  'thestreetforce': 186713,
#  'weeks': 203642,
#  'child': 40529,
#  'before': 25073,
#  'nancy': 130477,
#  'grac': 81490,
#  'woody': 207280,
#  'woodpecker': 207258,
#  '\x83': 213411,
#  'barber': 23004,
#  'seville': 166507,
#  'wishing': 206482,
#  '®': 214900,
#  '7g6r0': 6853,
#  'staying': 177318,
#  'drexel': 58933,
#  'fabulous': 67552,
#  'university': 196860,
#  'happened': 85670,
#  'angels': 15278,
#  'demons': 53533,
#  'lions': 112974,
#  'tigers': 187999,
#  'bears': 24348,
#  'minimizes': 124340,
#  'impact': 95347,
#  'dibs': 54941,
#  'voltron': 200870,
#  'arm': 17660,
#  'leg': 111152,
#  'wait': 201853,
#  'manners': 118923,
#  'saw': 163450,
#  'mum': 128608,
#  'fat': 68763,
#  'asses': 18734,
#  'nai': 130207,
#  'three': 187368,
#  'external': 67098,
#  'monitors': 126336,
#  'laptop': 109868,
#  'win7rc': 206096,
#  '1920x1080': 1602,
#  '1280x1024': 826,
#  'facebook': 67583,
#  'copic': 46599,
#  'marker': 119489,
#  'maybe': 120617,
#  'later': 110125,
#  'californians': 35854,
#  'making': 118174,
#  'fettucini': 69906,
#  'garlic': 76935,
#  'bread': 31859,
#  'bday': 24121,
#  'once': 137846,
#  'pants': 141397,
#  'ironically': 98208,
#  'job': 101761,
#  'fml': 72210,
#  'sweep': 181784,
#  'haha': 84519,
#  'gr8': 81445,
#  'science': 164332,
#  'cartoons': 37389,
#  'edinburgh': 61336,
#  'fringe': 74588,
#  'monies': 126312,
#  'btw': 33370,
#  'elliott': 62603,
#  'blame': 28259,
#  'intrusion': 97690,
#  'school': 164158,
#  'done': 57558,
#  'short': 168720,
#  'stack': 176716,
#  'thing': 186903,
#  'which': 204932,
#  'latter': 110216,
#  'store': 178235,
#  'thinking': 186973,
#  'less': 111633,
#  'than': 185883,
#  'chance': 39058,
#  'hedo': 87436,
#  'stays': 177326,
#  'orlando': 139079,
#  'wud': 208626,
#  'beautiful': 24458,
#  'plc': 146422,
#  'outer': 139590,
#  'servers': 166307,
#  'backup': 21800,
#  'experience': 66852,
#  'problems': 150111,
#  'delay': 53184,
#  'yes': 210790,
#  'gentle': 77946,
#  'breeze': 32061,
#  'blown': 29090,
#  'throug': 187474,
#  '7s7mn': 7212,
#  'morrea': 127098,
#  'joseph': 102381,
#  'vale': 198664,
#  'future': 75872,
#  'rooooooooomies': 160157,
#  'nyc': 135780,
#  'holler': 90220,
#  'cheese': 39861,
#  'burgers': 34299,
#  'lmbo': 113733,
#  'nothing': 134832,
#  'kind': 106373,
#  'sort': 174386,
#  'pick': 145102,
#  'flowers': 71993,
#  'teacher': 184209,
#  'jealous': 100490,
#  'without': 206597,
#  'having': 86567,
#  'hospital': 91369,
#  'them': 186442,
#  'talvez': 183190,
#  'seja': 165600,
#  '¦nfase': 214346,
#  'cifra': 41884,
#  'mas': 119862,
#  'atençõç\x9c': 19131,
#  'security': 165307,
#  'chain': 38911,
#  'strong': 178806,
#  'weakest': 203115,
#  'link': 112871,
#  'youtube': 211751,
#  'account': 9639,
#  'suspended': 181301,
#  'single': 170232,
#  'ladies': 109123,
#  'dance': 50964,
#  'sold': 173482,
#  'hoping': 91087,
#  'nervous': 131978,
#  'aim': 12157,
#  'talk': 183086,
#  '1000': 308,
#  'followers': 72494,
#  'grocery': 82594,
#  'blasted': 28346,
#  'oldies': 137402,
#  'sugar': 179868,
#  'ray': 154410,
#  'does': 57158,
#  'kashrut': 104323,
#  'convo': 46273,
#  'keep': 104947,
#  'kosher': 107777,
#  'roomies': 160106,
#  'catholic': 37781,
#  'pork': 148006,
#  'loin': 114113,
#  'fridge': 74418,
#  'isn': 98505,
#  'bitches': 27756,
#  'wake': 201931,
#  'early': 60704,
#  'opera': 138566,
#  'kay': 104604,
#  'immune': 95305,
#  'dentists': 53690,
#  'drills': 58984,
#  'etc': 65252,
#  'bother': 30931,
#  'gum': 83435,
#  'lift': 112308,
#  'surgery': 181118,
#  'tho': 187138,
#  'eek': 61664,
#  'tonite': 189727,
#  'hates': 86370,
#  'bebot': 24565,
#  'app': 16658,
#  'bhai': 26687,
#  'used': 198025,
#  'arre': 17837,
#  'kuch': 108348,
#  'kam': 103857,
#  'chilling': 40633,
#  'spanking': 174982,
#  'blackberry': 28066,
#  'unlimited': 196921,
#  'every': 65784,
#  'pop': 147830,
#  'quite': 152928,
#  'active': 10047,
#  'shame': 167005,
#  'mamma': 118529,
#  'mia': 123221,
#  'horny': 91217,
#  'island': 98464,
#  'letting': 111728,
#  'check': 39706,
#  'eureka': 65441,
#  'knowledge': 107319,
#  'referring': 155945,
#  'hey': 88593,
#  'thx': 187730,
#  'ttyl': 192423,
#  'sowwy': 174793,
#  'mothers': 127353,
#  'knew': 107129,
#  'sharepoint': 167216,
#  'written': 208386,
#  'interns': 97428,
#  'practising': 148838,
#  ...}

# %%
# transform the entire DataFrame of messages
sentiment_text_bow = bow_transformer.transform(tweetsdf['Sentiment Text'])

# check out the bag-of-words counts for the entire corpus as a large sparse matrix
print('Shape of Sparse Matrix: ', sentiment_text_bow.shape)
print('Amount of Non-Zero occurences: ', sentiment_text_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (993412, 216196)
# Amount of Non-Zero occurences:  8964919

# %%
# from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer().fit(sentiment_text_bow)

# to transform the entire bag-of-words corpus
sentiment_text_tfidf = tfidf_transformer.transform(sentiment_text_bow)
print(sentiment_text_tfidf.shape)
# Out:
# (993412, 216196)

# %% [markdown]
# ## Multinomial Naive Bayes

# %%
# Run Train Data Through Pipeline analyzer=text_process
# uncomment below to train on a larger dataset but it is very slow for a regular laptop

X_train, X_test, y_train, y_test = train_test_split(tweetsdf['Sentiment Text'], tweetsdf['Sentiment'], test_size=0.2)



# create pipeline
pipeline = Pipeline([
    ('bow', CountVectorizer(strip_accents='ascii',
                            stop_words='english',
                            lowercase=True)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# this is where we define the values for GridSearchCV to iterate over
parameters = {'bow__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'classifier__alpha': (1e-2, 1e-3),
             }

# do 2-fold cross validation for each of the 8 possible combinations of the above params
grid = GridSearchCV(pipeline, cv=2, param_grid=parameters, verbose=1)
grid.fit(X_train,y_train)

# summarize results
print("\nBest Model: %f using %s" % (grid.best_score_, grid.best_params_))
print('\n')
means = grid.cv_results_['mean_test_score']
stds = grid.cv_results_['std_test_score']
params = grid.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("Mean: %f Stdev:(%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  5.6min finished
# Best Model: 0.742639 using {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
#
#
# Mean: 0.730293 Stdev:(0.000219) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': True}
# Mean: 0.742639 Stdev:(0.000144) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
# Mean: 0.729915 Stdev:(0.000217) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.001, 'tfidf__use_idf': True}
# Mean: 0.739953 Stdev:(0.000127) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}
# Mean: 0.715138 Stdev:(0.000265) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': True}
# Mean: 0.731885 Stdev:(0.000216) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
# Mean: 0.707476 Stdev:(0.000324) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': True}
# Mean: 0.719033 Stdev:(0.000158) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}

# %%
# save best model to current working directory
joblib.dump(grid, "twitter_sentiment.pkl")
# Out:
# ['twitter_sentiment.pkl']

# %% [markdown]
# #### Accuracy Score and Confusion Matrix

# %%
# load from file and predict using the best configs found in the CV step
model_NB = joblib.load("twitter_sentiment.pkl" )

# get predictions from best model above
y_preds = model_NB.predict(X_test)

print('accuracy score: ',accuracy_score(y_test, y_preds))
print('\n')
print('confusion matrix: \n',confusion_matrix(y_test,y_preds))
print('\n')
print(classification_report(y_test, y_preds))
# Out:
# accuracy score:  0.7470040214814554
#
#
# confusion matrix:
#  [[67254 27325]
#  [22941 81163]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.75      0.71      0.73     94579
#           1       0.75      0.78      0.76    104104
#
# avg / total       0.75      0.75      0.75    198683

# %% [markdown]
# ## Linear Support Vector Classifier

# %%
from sklearn.svm import SVC
X_train, X_test, y_train, y_test = train_test_split(tweetsdf['Sentiment Text'][:20000], tweetsdf['Sentiment'][:20000], test_size=0.2)
# X_train, X_test, y_train, y_test = train_test_split(tweetsdf['Sentiment Text'], tweetsdf['Sentiment'], test_size=0.2)      # Extremely slow with the complete dataset
text_clf_SVC = Pipeline([('bow', CountVectorizer(strip_accents='ascii',stop_words='english',lowercase=True)),
                     ('tfidf', TfidfTransformer()),
                     ('classifier', SVC(kernel='linear')),
])
text_clf_SVC.fit(X_train, y_train)
print('Done!')
# Out:
# Done!

# %% [markdown]
# #### Accuracy Score and Confusion Matrix

# %%
# get predictions from best model above
y_preds_SVC = text_clf_SVC.predict(X_test)

print('accuracy score: ',accuracy_score(y_test, y_preds_SVC))
print('\n')
print('confusion matrix: \n',confusion_matrix(y_test,y_preds_SVC))
print('\n')
print(classification_report(y_test, y_preds_SVC))
# Out:
# accuracy score:  0.7105
#
#
# confusion matrix:
#  [[1540  558]
#  [ 600 1302]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.72      0.73      0.73      2098
#           1       0.70      0.68      0.69      1902
#
# avg / total       0.71      0.71      0.71      4000
